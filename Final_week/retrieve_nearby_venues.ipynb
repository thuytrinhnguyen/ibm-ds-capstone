# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
suburb = pd.read_csv('data/suburb.csv')

# %%
suburb
# Out:
#                                       href    latitude    longitude  \
# 0                          /wiki/Landsat_7         NaN          NaN
# 1                        /wiki/False-color         NaN          NaN
# 2                /wiki/Royal_National_Park         NaN          NaN
# 3    /wiki/Ku-ring-gai_Chase_National_Park         NaN          NaN
# 4       /wiki/Blue_Mountains_National_Park     33°37′S     150°28′E
# ..                                     ...         ...          ...
# 726               /wiki/City_of_Hawkesbury     33°25′S     150°47′E
# 727                  /wiki/The_Hills_Shire     33°46′S     151°00′E
# 728  /wiki/Municipality_of_Hunter%27s_Hill     33°49′S     151°08′E
# 729              /wiki/Ku-ring-gai_Council  33°45′15″S  151°09′06″E
# 730                   /wiki/City_of_Sydney     33°52′S     151°12′E
#
#                               suburb
# 0                          Landsat 7
# 1                        false-color
# 2                Royal National Park
# 3    Ku-ring-gai Chase National Park
# 4       Blue Mountains National Park
# ..                               ...
# 726                       Hawkesbury
# 727                        The Hills
# 728                    Hunter's Hill
# 729                      Ku-ring-gai
# 730                   City of Sydney
#
# [731 rows x 4 columns]

# %%
suburb = suburb[~suburb['latitude'].isna()]

# %%
suburb
# Out:
#                                              href    latitude    longitude  \
# 4              /wiki/Blue_Mountains_National_Park     33°37′S     150°28′E
# 6                                    /wiki/Sydney  33°51′54″S  151°12′34″E
# 7                           /wiki/City_of_Penrith     33°45′S     150°42′E
# 8          /wiki/Camden_Council_(New_South_Wales)     34°03′S     150°42′E
# 9    /wiki/City_of_Campbelltown_(New_South_Wales)     34°04′S     150°49′E
# ..                                            ...         ...          ...
# 726                      /wiki/City_of_Hawkesbury     33°25′S     150°47′E
# 727                         /wiki/The_Hills_Shire     33°46′S     151°00′E
# 728         /wiki/Municipality_of_Hunter%27s_Hill     33°49′S     151°08′E
# 729                     /wiki/Ku-ring-gai_Council  33°45′15″S  151°09′06″E
# 730                          /wiki/City_of_Sydney     33°52′S     151°12′E
#
#                            suburb
# 4    Blue Mountains National Park
# 6                          Sydney
# 7                 City of Penrith
# 8                  Camden Council
# 9            City of Campbelltown
# ..                            ...
# 726                    Hawkesbury
# 727                     The Hills
# 728                 Hunter's Hill
# 729                   Ku-ring-gai
# 730                City of Sydney
#
# [696 rows x 4 columns]

# %%
CLIENT_ID = 'QT00YVC2AY2FQHORW0EUGCOWUIE2ZQ0UFAQIDWR43EJRQAWO' # your Foursquare ID
CLIENT_SECRET = '3BP5F0GKG5BCT1ZJ1M41N4YWCOW0EQIQVDOOSJ21MD3I53Z0' # your Foursquare Secret
VERSION = '20210101' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value
lat = 43.676357
lng = 79.293031
radius = 500
LIMIT = 100

# %%
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)

# %%
print(url)
# Out:
# https://api.foursquare.com/v2/venues/explore?&client_id=QT00YVC2AY2FQHORW0EUGCOWUIE2ZQ0UFAQIDWR43EJRQAWO&client_secret=3BP5F0GKG5BCT1ZJ1M41N4YWCOW0EQIQVDOOSJ21MD3I53Z0&v=20210101&ll=43.676357,79.293031&radius=500&limit=100

# %%
r = requests.get(url)
html = BeautifulSoup(r)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-c1bf6b20689d> in <module>
#       1 r = requests.get(url)
# ----> 2 html = BeautifulSoup(r)
#
# ~\miniconda3\envs\ml\lib\site-packages\bs4\__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     308         if hasattr(markup, 'read'):        # It's a file-type object.
#     309             markup = markup.read()
# --> 310         elif len(markup) <= 256 and (
#     311                 (isinstance(markup, bytes) and not b'<' in markup)
#     312                 or (isinstance(markup, str) and not '<' in markup)
#
# TypeError: object of type 'Response' has no len()
